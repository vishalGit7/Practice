# %%
from PIL import Image

# %%
mac=Image.open('example.jpg')

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x12E7D7414C8>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
#CROPPING OF IMAGE
#mac.crop(x-axis,y-axis,width,height))
mac.crop((0,0,200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x12E7DE82D48>

# %%
pencils=Image.open('pencils.jpg')

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
x=0
y=0

width = 1950 / 3
height = 1300 / 3

pencils.crop((x,y,width,height))
# Out:
# <PIL.Image.Image image mode=RGB size=650x433 at 0x12E7D2EEC08>

# %%
#lets take bottom of image
x = 0
y = 1100
width = 1950 / 3
height = 1300

pencils.crop((x,y,width,height))
# Out:
# <PIL.Image.Image image mode=RGB size=650x200 at 0x12E7DC513C8>

# %%
from PIL import Image

# %%
red=Image.open('red_color.jpg')

# %%
blue=Image.open('blue_color.png')

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x2AA646E2E48>

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x2AA646E6488>

# %%
# Out:
#   File "<ipython-input-31-b4183adc4f6b>", line 1
#     red.paste(im=blue,(0,0))
#                      ^
# SyntaxError: positional argument follows keyword argument

# %%
blue.paste(im=red,box=(0,0),mask=red)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-92f914756e73> in <module>
# ----> 1 blue.paste(im=red,box=(0,0),mask=red)
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in paste(self, im, box, mask)
#    1464         if mask:
#    1465             mask.load()
# -> 1466             self.im.paste(im, box, mask.im)
#    1467         else:
#    1468             self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x2AA646E6488>
